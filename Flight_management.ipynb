# %% [markdown]
# <a href="https://colab.research.google.com/github/25janet/Alx_Data_Engineering_Python/blob/main/Flight_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Python Tuple Challenge: Delivery Drone Tracker

A delivery company stores drone movement coordinates as tuples.

Each coordinate represents (x, y) on a grid.
Example flight path:
# Out:
#   File "/tmp/ipykernel_455/2112902411.py", line 1
#     Python Tuple Challenge: Delivery Drone Tracker
#            ^
# SyntaxError: invalid syntax

# %%
flight_path = ((0, 0), (0, 1), (0, 2), (1, 2), (2, 2), (2, 1), (2, 0), (2, 0))

# %% [markdown]
# **Verify the data is a tuple**
#
# Write code that checks if flight_path is actually a tuple.
#
# If it is not, print: *Invalid flight data*

# %%
if not isinstance(flight_path,tuple):
    print("Invalid path")

# %% [markdown]
# **Print the first and last coordinates**

# %%
print(f"The first and the last coordinates are as follows respectively: {flight_path[0], flight_path[-1]}")
# Out:
# The first and the last coordinates are as follows respectively: ((0, 0), (2, 0))

# %% [markdown]
# Print the coordinates excluding the first and last positions.

# %%
print(flight_path[1:-1])
# Out:
# ((0, 1), (0, 2), (1, 2), (2, 2), (2, 1), (2, 0))

# %% [markdown]
# Count how many times the drone visited the same location

# %%
flight_path.count((2,0))
# Out:
# 2

# %% [markdown]
# Print the first x and y coordinates

# %%
x,y=flight_path[0]
print(f"Starting x:{x}")
print(f"Starting y:{y}")
# Out:
# Starting x:0
# Starting y:0

# %% [markdown]
# Add another flight path

# %%
return_path = ((1,0), (0,0))
full_path = flight_path + return_path
print(full_path)
# Out:
# ((0, 0), (0, 1), (0, 2), (1, 2), (2, 2), (2, 1), (2, 0), (2, 0), (1, 0), (0, 0))
